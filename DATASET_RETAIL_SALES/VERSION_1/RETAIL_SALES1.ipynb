# %% [markdown]
# # Warehouse-and-Retail-Sales
# ### URL DATASET →  https://catalog.data.gov/dataset/warehouse-and-retail-sales

# %% [markdown]
# ### INFORMACIÓN ESTRUCTURA DE LOS DATOS → https://data.montgomerycountymd.gov/Community-Recreation/Warehouse-and-Retail-Sales/v76h-r7br/about_data
#
# <img src="..\IMG\Columns.png">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('K:\😈😈😈\AI\CIENCIA_DATOS\PRACTICA\PROJECT\DATASET\DATASET\RETAIL_SALES\Warehouse_and_Retail_Sales.csv')
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# 1                         MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2               S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3                     SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4                    SANTORINI GAVALA WHITE - 750ML      WINE          0.82
# ...                                             ...       ...           ...
# 307640  ST PETERS ORGANIC ENG ALE NR 12/CS - 16.9OZ      BEER          0.00
# 307641               STELLA ARTOIS 2/12 NR - 11.2OZ      BEER        372.45
# 307642                       TECATE 4/6 LNNR - 12OZ      BEER          7.79
# 307643     S SMITH WINTER WELCOME NR 12/CS - 18.7OZ      BEER          0.00
# 307644          S SMITH WINTER WELCOME 4/6NR - 12OZ      BEER          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    0.0             2.00
# 1                    1.0             4.00
# 2                    0.0             1.00
# 3                    0.0             1.00
# 4                    0.0             0.00
# ...                  ...              ...
# 307640               0.0             1.00
# 307641             315.0          3586.88
# 307642               0.0             4.00
# 307643               0.0             2.00
# 307644               0.0             1.00
#
# [307645 rows x 9 columns]

# %% [markdown]
# #### ENTENDER CÓMO ES LA ESTRUCUTRA DE LA DATASET (TIPO DE VARIABLES, CANTIDAD DE DATOS Y COLUMNAS)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %% [markdown]
# #### INFORMACIÓN GENERAL DE LA DATASET (PROMEDIO, DESVIACIÓN ESTÁNDAR, MÍNIMO, MÁXIMO, ETC..)

# %%
df.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307642.000000     307645.000000
# mean     2018.438525       6.423862       7.024071          6.936465
# std         1.083061       3.461812      30.986238         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.267500          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %% [markdown]
# #### CONOCER CUANTOS ELEMENTOS NO TIENEN VALOR POR COLUMNA

# %%
df.isna().sum()
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM CODE             0
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %% [markdown]
# ES INCORRECTO LOS VALORES PASADOS, YA QUE HAY MÁS VALORES EN CERO POR COLUMNA.

# %% [markdown]
# #### VAMOS A REVOLVER LA DATASET

# %%
# REVOLVER VALORES O SHUFFLED
df=df.iloc[np.random.permutation(df.index)].reset_index(drop=True)
df
# Out:
#         YEAR  MONTH                              SUPPLIER ITEM CODE  \
# 0       2019      7                              DOPS INC      3476
# 1       2019     10                       BACKUP BEVERAGE     61911
# 2       2017      9                              DOPS INC     46084
# 3       2019      9        JACKSON FAMILY ENTERPRISES INC     39837
# 4       2019      7                   BRONCO WINE COMPANY    308310
# ...      ...    ...                                   ...       ...
# 307640  2017     11     REPUBLIC NATIONAL DISTRIBUTING CO    320734
# 307641  2019     11                   MASS BAY BREWING CO     92649
# 307642  2019      4                    ANHEUSER BUSCH INC     26145
# 307643  2019      7  THE COUNTRY VINTNER, LLC DBA WINEBOW    192872
# 307644  2019      5                    ANHEUSER BUSCH INC     23075
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                          JEVER PILSNER 50L KEG      KEGS          0.00
# 1       POTTERS GRAPEFRUIT HIBISCUS 12/16.9OZ NR      BEER          0.00
# 2                        HEAVYWEIGHT RED - 750ML      WINE          0.00
# 3                   MATANZAS CREEK S/BLC - 750ML      WINE         11.53
# 4                 GARNET MONTEREY P/NOIR - 750ML      WINE          0.00
# ...                                          ...       ...           ...
# 307640      CYT CASILLERO DEL DIABLO RED - 750ML      WINE          0.00
# 307641        HARPOON WINTER WARMER 4/6NR - 12OZ      BEER         18.04
# 307642                  BUD 18PK 16OZ CAN - 16OZ      BEER          0.00
# 307643        MOCALI BRUN DI MONTAL DOCG - 750ML      WINE          0.00
# 307644             LANDSHARK LAGER 4/6 NR - 12OZ      BEER         58.25
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    0.0             1.00
# 1                    0.0             1.00
# 2                    0.0             1.00
# 3                   10.0            12.00
# 4                    0.0             6.00
# ...                  ...              ...
# 307640               0.0             1.00
# 307641              13.0            72.00
# 307642               0.0           822.61
# 307643               0.0             0.00
# 307644              54.0           166.00
#
# [307645 rows x 9 columns]

# %% [markdown]
# #### VAMOS EMPEZAR A ELIMINAR COLUMNAS QUE NO APORTEN INFORMACIÓN RELEVANTE

# %%
df['ITEM CODE'].mode()
# Out:
# 0       100293
# 1       100749
# 2        10103
# 3       101532
# 4        10197
#          ...
# 4591     99740
# 4592     99753
# 4593      9997
# 4594     99970
# 4595        WC
# Name: ITEM CODE, Length: 4596, dtype: object

# %%
df=df.drop('ITEM CODE', axis=1)
df
# Out:
#         YEAR  MONTH                              SUPPLIER  \
# 0       2019      7                              DOPS INC
# 1       2019     10                       BACKUP BEVERAGE
# 2       2017      9                              DOPS INC
# 3       2019      9        JACKSON FAMILY ENTERPRISES INC
# 4       2019      7                   BRONCO WINE COMPANY
# ...      ...    ...                                   ...
# 307640  2017     11     REPUBLIC NATIONAL DISTRIBUTING CO
# 307641  2019     11                   MASS BAY BREWING CO
# 307642  2019      4                    ANHEUSER BUSCH INC
# 307643  2019      7  THE COUNTRY VINTNER, LLC DBA WINEBOW
# 307644  2019      5                    ANHEUSER BUSCH INC
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                          JEVER PILSNER 50L KEG      KEGS          0.00
# 1       POTTERS GRAPEFRUIT HIBISCUS 12/16.9OZ NR      BEER          0.00
# 2                        HEAVYWEIGHT RED - 750ML      WINE          0.00
# 3                   MATANZAS CREEK S/BLC - 750ML      WINE         11.53
# 4                 GARNET MONTEREY P/NOIR - 750ML      WINE          0.00
# ...                                          ...       ...           ...
# 307640      CYT CASILLERO DEL DIABLO RED - 750ML      WINE          0.00
# 307641        HARPOON WINTER WARMER 4/6NR - 12OZ      BEER         18.04
# 307642                  BUD 18PK 16OZ CAN - 16OZ      BEER          0.00
# 307643        MOCALI BRUN DI MONTAL DOCG - 750ML      WINE          0.00
# 307644             LANDSHARK LAGER 4/6 NR - 12OZ      BEER         58.25
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    0.0             1.00
# 1                    0.0             1.00
# 2                    0.0             1.00
# 3                   10.0            12.00
# 4                    0.0             6.00
# ...                  ...              ...
# 307640               0.0             1.00
# 307641              13.0            72.00
# 307642               0.0           822.61
# 307643               0.0             0.00
# 307644              54.0           166.00
#
# [307645 rows x 8 columns]

# %% [markdown]
# SE VA ELIMINAR ITEM CODE DEBIDO A QUE SON CÓDIGOS QUE SE REPITEN VARIADAMENTE, NO HAY UNA TENDENCIA

# %%
R=df['ITEM DESCRIPTION'].mode() # CONOCER LA MODA
G=df['ITEM DESCRIPTION'].nunique() # CONOCER CUANTOS ELEMENTOS ÚNICOS HAY EN LA COLUMNA
print(f''' 
    Moda {R}
    Total de elementos únicos {G} vs total {df['ITEM DESCRIPTION'].count()} 
''')
# Out:
#
#     Moda 0    BURGANS ALBARINO - 750ML
# Name: ITEM DESCRIPTION, dtype: object
#     Total de elementos únicos 34822 vs total 307645

# %% [markdown]
# Eliminamos el único valor de ITEM TYPE

# %%
d =df[df['ITEM TYPE'].isna()].index
print(df.isna().sum())
df = df.drop(d)
print(df.isna().sum())
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM DESCRIPTION      0
# ITEM TYPE             0
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %% [markdown]
# VAMOS EVALUAR SUPPLIER

# %%
d =df[df['SUPPLIER'].isna()].index
for i in d.values:
    row = df.loc[i]
    # Contar el número de elementos vacíos en esa fila
    num_empty_elements = row.isna().sum()
    if num_empty_elements >1:
        print(f'Número de elementos vacíos en la fila {i}: {num_empty_elements}')  # Salida: 2
print(df['SUPPLIER'].isna().sum())
# Out:
# Número de elementos vacíos en la fila 117922: 2
# Número de elementos vacíos en la fila 232898: 2
# Número de elementos vacíos en la fila 248476: 2
# 167

# %% [markdown]
# SON 167 ELEMENTOS SIN NOMBRE DE 300,000 APROXIMADAMENTE, 3 ELEMENTOS QUE CUENTAN CON DOS ELEMENTOS VACIOS, A ESTOS LOS VAMOS A ELIMINAR
# EVALUAR SUPPLIER Y CAMBIAR LOS 164 ELEMENTOS PARA NO PERDER MUESTRAS, EN CASO DE NO ENCONTRAR CORRELACIÓN ELEMINARLAS YA QUE REPRESENTAN APROXIMADAMENTE UN  0.05466 % DE LAS MUESTRA TOTALES

# %%
for i in d.values:
    row = df.loc[i]
    # Contar el número de elementos vacíos en esa fila
    num_empty_elements = row.isna().sum()
    if num_empty_elements >1:
        print(f'Número de elementos vacíos en la fila {i}: {num_empty_elements}')  # Salida: 2
        df = df.drop([i])

print(df.isna().sum())
# Out:
# Número de elementos vacíos en la fila 117922: 2
# Número de elementos vacíos en la fila 232898: 2
# Número de elementos vacíos en la fila 248476: 2
# YEAR                  0
# MONTH                 0
# SUPPLIER            164
# ITEM DESCRIPTION      0
# ITEM TYPE             0
# RETAIL SALES          0
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %% [markdown]
# OPTÉ POR ELMINAR 164 MUESTRAS DEL SAMPLE

# %%
df=df.dropna(subset=['SUPPLIER'])

print(df.isna().sum())
# Out:
# YEAR                0
# MONTH               0
# SUPPLIER            0
# ITEM DESCRIPTION    0
# ITEM TYPE           0
# RETAIL SALES        0
# RETAIL TRANSFERS    0
# WAREHOUSE SALES     0
# dtype: int64

# %% [markdown]
# SUSTUIMOS TODOS LOS ELEMENTOS FALTANTES POR ALGÚN ELEMENTO DE LA COLUMNA ALEATORIAMENTE❌

# %%
'''
# Identificar los valores que no se repiten en la columna 'SUPPLIER'
unique_values = df['SUPPLIER'].value_counts()[df['SUPPLIER'].value_counts() == 1].index.tolist()

# Obtener los índices de las filas con valores faltantes en la columna 'SUPPLIER'
missing_indices = df[df['SUPPLIER'].isna()].index

# Reemplazar los valores faltantes con valores aleatorios de unique_values
for idx in missing_indices:
    df.at[idx, 'SUPPLIER'] = rd.choice(unique_values)

print("DataFrame después de reemplazar los valores faltantes:")
print(df)
'''
# Out:
# '\n# Identificar los valores que no se repiten en la columna \'SUPPLIER\'\nunique_values = df[\'SUPPLIER\'].value_counts()[df[\'SUPPLIER\'].value_counts() == 1].index.tolist()\n\n# Obtener los índices de las filas con valores faltantes en la columna \'SUPPLIER\'\nmissing_indices = df[df[\'SUPPLIER\'].isna()].index\n\n# Reemplazar los valores faltantes con valores aleatorios de unique_values\nfor idx in missing_indices:\n    df.at[idx, \'SUPPLIER\'] = rd.choice(unique_values)\n\nprint("DataFrame después de reemplazar los valores faltantes:")\nprint(df)\n'

# %%
df.isna().sum()
# Out:
# YEAR                0
# MONTH               0
# SUPPLIER            0
# ITEM DESCRIPTION    0
# ITEM TYPE           0
# RETAIL SALES        0
# RETAIL TRANSFERS    0
# WAREHOUSE SALES     0
# dtype: int64

# %% [markdown]
# CAMBIAREMOS LOS DATOS POR NUMEROS PARA PODER PROCESAR LA INFORMACION.

# %%
q=[]
# Obtiene los valor que no se repitan 
for i in df['ITEM DESCRIPTION'].values: 
    if i not in q:
        q.append(i)
item_dict = {item: index + 1 for index, item in enumerate( q)}
df['ITEM DESCRIPTION'] = df['ITEM DESCRIPTION'].map(item_dict)


qp=[]
# Obtiene los valor que no se repitan 
for i in df['SUPPLIER'].values: 
    if i not in qp:
        qp.append(i)

item_dict = {item: index + 1 for index, item in enumerate( qp)}
df['SUPPLIER'] = df['SUPPLIER'].map(item_dict)


e=[]
# Obtiene los valor que no se repitan 
for i in df['ITEM TYPE'].values: 
    if i not in e:
        e.append(i)


item_dict = {item: index + 1 for index, item in enumerate(e)}
df['ITEM TYPE'] = df['ITEM TYPE'].map(item_dict)
df
# Out:
#         YEAR  MONTH  SUPPLIER  ITEM DESCRIPTION  ITEM TYPE  RETAIL SALES  \
# 0       2019      7         1                 1          1          0.00
# 1       2019     10         2                 2          2          0.00
# 2       2017      9         1                 3          3          0.00
# 3       2019      9         3                 4          3         11.53
# 4       2019      7         4                 5          3          0.00
# ...      ...    ...       ...               ...        ...           ...
# 307640  2017     11        18              4893          3          0.00
# 307641  2019     11        74             12053          2         18.04
# 307642  2019      4        15              5031          2          0.00
# 307643  2019      7        19             21573          3          0.00
# 307644  2019      5        15              8493          2         58.25
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    0.0             1.00
# 1                    0.0             1.00
# 2                    0.0             1.00
# 3                   10.0            12.00
# 4                    0.0             6.00
# ...                  ...              ...
# 307640               0.0             1.00
# 307641              13.0            72.00
# 307642               0.0           822.61
# 307643               0.0             0.00
# 307644              54.0           166.00
#
# [307477 rows x 8 columns]

# %% [markdown]
# HACEMOS SUBDIVISION DE ELEMENTOS DE TEST, TRAIN Y VALIDACIÓN

# %%
# REVOLVER VALORES O SHUFFLED
# Establecer la semilla para reproducibilidad
np.random.seed(42)

# Mezclar el DataFrame
df= df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# # Visualizar correlaciones antes de dropiar columnas

# %%
correlacion_data=df.corr()
print(correlacion_data)
plt.matshow(correlacion_data)
plt.xticks(range(len(df.columns)), df.columns, rotation=90)
plt.yticks(range(len(df.columns)), df.columns)
plt.show()
# Out:
#                       YEAR     MONTH  SUPPLIER  ITEM DESCRIPTION  ITEM TYPE  \
# YEAR              1.000000 -0.386082  0.000290         -0.026654  -0.010404
# MONTH            -0.386082  1.000000  0.005504          0.028330  -0.000916
# SUPPLIER          0.000290  0.005504  1.000000          0.036567  -0.026864
# ITEM DESCRIPTION -0.026654  0.028330  0.036567          1.000000  -0.130245
# ITEM TYPE        -0.010404 -0.000916 -0.026864         -0.130245   1.000000
# RETAIL SALES      0.003717  0.011550  0.021153         -0.081877   0.035275
# RETAIL TRANSFERS  0.003725  0.009911  0.024560         -0.080742   0.038695
# WAREHOUSE SALES   0.006846  0.003579  0.003338         -0.035669  -0.133513
#
#                   RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# YEAR                  0.003717          0.003725         0.006846
# MONTH                 0.011550          0.009911         0.003579
# SUPPLIER              0.021153          0.024560         0.003338
# ITEM DESCRIPTION     -0.081877         -0.080742        -0.035669
# ITEM TYPE             0.035275          0.038695        -0.133513
# RETAIL SALES          1.000000          0.979434         0.501256
# RETAIL TRANSFERS      0.979434          1.000000         0.493001
# WAREHOUSE SALES       0.501256          0.493001         1.000000

# %% [markdown]
# Observamos todas aquellas que tienen correlación positiva con la variable de predicción.

# %%
a = correlacion_data[correlacion_data >= 0]
print('RETAIL_SALES')
print(a['RETAIL SALES'])
# Out:
# RETAIL_SALES
# YEAR                0.003717
# MONTH               0.011550
# SUPPLIER            0.021153
# ITEM DESCRIPTION         NaN
# ITEM TYPE           0.035275
# RETAIL SALES        1.000000
# RETAIL TRANSFERS    0.979434
# WAREHOUSE SALES     0.501256
# Name: RETAIL SALES, dtype: float64

# %%
#pd.plotting.scatter_matrix(df)
for i in df.columns:
    plt.scatter(df[i].values,df['RETAIL SALES'])
    plt.title(f'''RETAIL SALES vs {i} ''')
    plt.ylabel('RETAIL SALES')
    plt.xlabel(f'''{i}''')
    plt.grid()
    plt.show()

# %%
import statsmodels.api as sm
# Definir variables

df_X=df.drop(columns=['RETAIL SALES'])
print('TABLA DF X')
print(df_X)
x = sm.add_constant(df_X)  # Añadir la constante
print(x)

y = df['RETAIL SALES']

# Alinear los datos
x, y = x.align(y, join='inner', axis=0)


# Ajustar el modelo
model = sm.OLS(y, x).fit()

# Mostrar resumen del modelo
model.summary()
# Out:
# TABLA DF X
#         YEAR  MONTH  SUPPLIER  ITEM DESCRIPTION  ITEM TYPE  RETAIL TRANSFERS  \
# 0       2017     10        34              3677          3             14.84
# 1       2017     12       131              5382          3              0.00
# 2       2017      7        69             15443          4             47.92
# 3       2019     11        76              9783          2              7.00
# 4       2019      2        34             11732          3              4.00
# ...      ...    ...       ...               ...        ...               ...
# 307472  2019      1        31              9228          3              0.00
# 307473  2019      4        48               391          3              5.00
# 307474  2020      1        33             12895          4             11.75
# 307475  2019      2        24             14206          3              0.00
# 307476  2019      6        27             17504          3             20.00
#
#         WAREHOUSE SALES
# 0                   2.0
# 1                   2.0
# 2                   1.0
# 3                  31.0
# 4                  13.0
# ...                 ...
# 307472              0.0
# 307473              4.0
# 307474              0.0
# 307475              1.0
# 307476             31.0
#
# [307477 rows x 7 columns]
#         const  YEAR  MONTH  SUPPLIER  ITEM DESCRIPTION  ITEM TYPE  \
# 0         1.0  2017     10        34              3677          3
# 1         1.0  2017     12       131              5382          3
# 2         1.0  2017      7        69             15443          4
# 3         1.0  2019     11        76              9783          2
# 4         1.0  2019      2        34             11732          3
# ...       ...   ...    ...       ...               ...        ...
# 307472    1.0  2019      1        31              9228          3
# 307473    1.0  2019      4        48               391          3
# 307474    1.0  2020      1        33             12895          4
# 307475    1.0  2019      2        24             14206          3
# 307476    1.0  2019      6        27             17504          3
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                  14.84              2.0
# 1                   0.00              2.0
# 2                  47.92              1.0
# 3                   7.00             31.0
# 4                   4.00             13.0
# ...                  ...              ...
# 307472              0.00              0.0
# 307473              5.00              4.0
# 307474             11.75              0.0
# 307475              0.00              1.0
# 307476             20.00             31.0
#
# [307477 rows x 8 columns]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           RETAIL SALES   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                 1.048e+06
# Date:                Tue, 03 Sep 2024   Prob (F-statistic):               0.00
# Time:                        10:40:37   Log-Likelihood:            -9.9208e+05
# No. Observations:              307477   AIC:                         1.984e+06
# Df Residuals:                  307469   BIC:                         1.984e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -42.5618     22.225     -1.915      0.055     -86.122       0.998
# YEAR                 0.0212      0.011      1.923      0.054      -0.000       0.043
# MONTH                0.0198      0.003      5.764      0.000       0.013       0.027
# SUPPLIER            -0.0014      0.000     -7.110      0.000      -0.002      -0.001
# ITEM DESCRIPTION -1.069e-05   1.41e-06     -7.568      0.000   -1.35e-05   -7.92e-06
# ITEM TYPE            0.0290      0.016      1.863      0.062      -0.002       0.060
# RETAIL TRANSFERS     0.9717      0.000   2303.722      0.000       0.971       0.973
# WAREHOUSE SALES      0.0030   5.15e-05     57.809      0.000       0.003       0.003
# ==============================================================================
# Omnibus:                   165121.318   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3097767803.853
# Skew:                          -0.542   Prob(JB):                         0.00
# Kurtosis:                     494.725   Cond. No.                     2.80e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Vamos a eliminar las columnas SUPPLIER, YEAR, MONTH y ITEM DESCRIPTION, ya que no tiene una correlación positiva con mi variable a predecir.

# %% [markdown]
# Multiconealidad

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = sm.add_constant(df_X)
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]



for num,i in enumerate(vif_data['VIF']):
    if i>10:
        print('Multiconealidad',num,i)
    elif i>5:
        print('Correlación moderada que podría ser preocupante',num,i)
    elif 1<i and i<5:
        print(' Cierta correlación entre la variable independiente,no es la suficiente para ser preocupante',num,i)
    else:
        print('Escenario idela',num,i)
print(vif_data)
# Out:
# Multiconealidad 0 18.985881302863753
#  Cierta correlación entre la variable independiente,no es la suficiente para ser preocupante 1 1.0333319985464537
#  Cierta correlación entre la variable independiente,no es la suficiente para ser preocupante 2 1.340791379375244
#  Cierta correlación entre la variable independiente,no es la suficiente para ser preocupante 3 1.3630816320656496
#            Variable        VIF
# 0             const  18.985881
# 1         ITEM TYPE   1.033332
# 2  RETAIL TRANSFERS   1.340791
# 3   WAREHOUSE SALES   1.363082

# %%
df.describe()
# Out:
#                 YEAR          MONTH       SUPPLIER  ITEM DESCRIPTION  \
# count  307477.000000  307477.000000  307477.000000     307477.000000
# mean     2018.438238       6.424064      51.296116      11262.916293
# std         1.083080       3.461853      56.871852       7880.771928
# min      2017.000000       1.000000       1.000000          1.000000
# 25%      2017.000000       3.000000      18.000000       4808.000000
# 50%      2019.000000       7.000000      28.000000       9999.000000
# 75%      2019.000000       9.000000      62.000000      16413.000000
# max      2020.000000      12.000000     396.000000      34805.000000
#
#            ITEM TYPE   RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# count  307477.000000  307477.000000     307477.000000    307477.000000
# mean        3.024825       7.003644          6.938177        25.375561
# std         0.724153      30.387012         30.244239       249.500572
# min         1.000000      -6.490000        -38.490000     -4996.000000
# 25%         3.000000       0.000000          0.000000         0.000000
# 50%         3.000000       0.320000          0.000000         1.000000
# 75%         3.000000       3.260000          3.000000         5.000000
# max         8.000000    1816.490000       1990.830000     18317.000000

# %%
# Calcular el tamaño de los conjuntos
total_size = len(df)
test_size = int(total_size * 0.15)
validation_size = int(total_size * 0.10)
train_size = total_size - test_size - validation_size

# Dividir en entrenamiento, validación y prueba
df_train = df[:train_size]
df_val = df[train_size:train_size + validation_size]
df_test = df[train_size + validation_size:]

# %%
# ENTRENAMIENTO 75%
# Separar características y variable objetivo
X_train = df_train.drop(columns=['RETAIL SALES'])
y_train = df_train['RETAIL SALES']

# %%
# VALIDACION 10% 
X_val = df_val.drop(columns=['RETAIL SALES'])
y_val = df_val['RETAIL SALES']

# %%
# TEST 15%
X_test = df_test.drop(columns=['RETAIL SALES'])
y_test = df_test['RETAIL SALES']

# %%
print(f"Tamaño del conjunto de entrenamiento: {X_train.shape[0]}")
print(f"Tamaño del conjunto de validación: {X_val.shape[0]}")
print(f"Tamaño del conjunto de prueba: {X_test.shape[0]}")
# Out:
# Tamaño del conjunto de entrenamiento: 230609
# Tamaño del conjunto de validación: 30747
# Tamaño del conjunto de prueba: 46121

# %% [markdown]
# # DATASET
# ## Variable dependiente
# * REATAIL SALES
# ## Variable independiende
# * ITEM TYPE
# * RETAIL TRANSFERS
# * WAREHOUSE SALES
# * YEAR
# * MONTH
# * SUPPLIER
# * ITEM DESCRIPTION
